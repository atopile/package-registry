# %%
import firebase_admin
from firebase_admin import credentials, firestore


service_account_path = "/Users/narayanpowderly/Documents/atopile-workspace/package-registry-backend/atopile-880ca67acfe2.json"

if not firebase_admin._apps:  # Check if already initialized to prevent reinitialization
    cred = credentials.Certificate(service_account_path)
    firebase_admin.initialize_app(cred)

db = firestore.client()
_components_db = db.collection(
    "components"
)

# %%
import math

def get_resistor_or_capacitor(req_json, firestore_client):
    # Get the component requirements
    min_value = req_json.get("min_value")
    max_value = req_json.get("max_value")
    package = req_json.get("package", "").lstrip('C').lstrip('R')  # Strip leading 'R' if package is specified
    voltage = req_json.get("voltage")
    voltage_factor_of_safety = req_json.get("voltage_factor_of_safety", 2)
    dielectric = req_json.get("dielectric")

    # Query and filter
    query = firestore_client.collection("components").where("type", "==", req_json.get("type"))
    results = query.stream()
    components = [doc.to_dict() for doc in results]
    filtered_components = []
    for component in components:
        try:
            valid = True
            component_min_value = component.get("min_value")
            component_max_value = component.get("max_value")

            # Adjusted conditions
            if (component_min_value is None or math.isnan(component_min_value) or
                min_value is not None and component_min_value < min_value):
                valid = False
            if (component_max_value is None or math.isnan(component_max_value) or
                max_value is not None and component_max_value > max_value):
                valid = False
            if package and component.get("Package") != package:
                valid = False
            if component.get("Stock", 0) <= 100:  # Check stock only if other conditions are met
                valid = False
            if voltage and component.get("voltage") < voltage * voltage_factor_of_safety:
                valid = False
            if dielectric and component.get("dielectric") != dielectric:
                valid = False
            if valid:
                filtered_components.append(component)
        except (TypeError, ValueError, KeyError):
            continue

    # Select the best component
    basic_components = [component for component in filtered_components if component.get("basic-extended") == "Basic"]
    if basic_components:
        best_component = min(basic_components, key=lambda component: component["Price (USD)"])
    else:
        best_component = min(filtered_components, key=lambda component: component["Price (USD)"]) if filtered_components else None

    return {"Best Component": best_component}

# %%
payload = {
    "type": "Capacitor",
    "min_value": 0.00000176,
    "max_value": 0.00000264,
    "voltage": 50,
    # "dielectric": "X7R",
    # "package": "0402"
}

get_resistor_or_capacitor(payload, db)
# Out:
# {'Best Component': {'value': 2.2,
#   'type': 'Capacitor',
#   'basic-extended': 'Extended Part',
#   'Description': 'Multilayer Ceramic Capacitors MLCC - SMD/SMT 2.2uF 100V 1210 RoHS',
#   'Price (USD)': nan,
#   'Stock': nan,
#   'code': nan,
#   'Datasheet': nan,
#   'Type': nan,
#   'Package': '1210',
#   'voltage': 100.0,
#   'min_value': 1.98e-06,
#   'MFR.Part #': 'CL32B225KCJSNNE',
#   'tolerance': 10.0,
#   'value_in_ohms': nan,
#   'unit': 'uF',
#   'LCSC Part #': 'C55151',
#   'Comment': '2.2uF(225) ±10% 100V X7R',
#   'value_in_farads': 2.2e-06,
#   'Category': 'Multilayer Ceramic Capacitors MLCC - SMD/SMT',
#   'dielectric': 'X7R',
#   'max_value': 2.42e-06}}

# %%
import json
import math

def get_mosfet(req_json, firestore_client):
    try:
        # Retrieve the request parameters
        polarity = req_json.get("polarity")
        ds_voltage = req_json.get("drain_source_voltage_V")
        current = req_json.get("current_A")
        on_resistance = req_json.get("on_resistance_ohms")
        power_dissipation = req_json.get("power_dissipation_W")
        safety_factor_current = req_json.get("safety_factor", 1.5)
        safety_factor_voltage = req_json.get("safety_factor", 1.5)
        package = req_json.get("Package")

        if not polarity:
            raise ValueError("Polarity is required.")

        # Query the collection
        query = firestore_client.collection("mosfets").where("polarity", "==", polarity)
        results = query.stream()
        components = [doc.to_dict() for doc in results]
        print(len(components))
        # Filter components based on provided criteria
        filtered_components = []
        for component in components:
            valid = True
            if ds_voltage is not None and component.get("drain_source_voltage_V", 0) < ds_voltage * safety_factor_voltage:
                valid = False
            if current is not None and component.get("current_A", 0) < current * safety_factor_current:
                valid = False
            if on_resistance is not None and component.get("on_resistance_ohms", float('inf')) > on_resistance:
                valid = False
            if power_dissipation is not None and component.get("power_dissipation_W", 0) < power_dissipation:
                valid = False
            if component.get("Stock", 0) <= 100:
                valid = False
            if package and component.get("Package") != package:
                valid = False
            if valid:
                filtered_components.append(component)

        # Select the best component
        if not filtered_components:
            return "No suitable MOSFETs found."
            # return https_fn.Response(
            #     json.dumps({"error": "No suitable MOSFETs found."}),
            #     status=404,
            #     content_type='application/json'
            # )

        best_mosfet = min(filtered_components, key=lambda component: component["Price"][0]["price"] if component["Price"] else float('inf'))

        # Send back a JSON response with the best MOSFET
        return best_mosfet
        # return https_fn.Response(
        #     json.dumps({"Best MOSFET": best_mosfet}),
        #     status=200,
        #     content_type='application/json'
        # )

    except Exception as e:
        return "error" + str(e)
        # return https_fn.Response(
        #     json.dumps({"error": str(e)}),
        #     status=400,
        #     content_type='application/json'
        # )

# %%
#

query = {
    "polarity": "N Channel",
    "drain_source_voltage_V": 20,
    "current_A": 20,
    "on_resistance_ohms": 0.1,
    "power_dissipation_W": 23,
    "Package": "PDFN-8(5.2x6.2)"
}

get_mosfet(query, db)
# Out:
# /Users/narayanpowderly/Documents/atopile-workspace/.venv/lib/python3.11/site-packages/google/cloud/firestore_v1/base_collection.py:295: UserWarning: Detected filter using positional arguments. Prefer using the 'filter' keyword argument instead.
#   return query.where(field_path, op_string, value)
# 429
# {'Assembly Type': 'SMT AssemblyA PCB assembly fixture is needed to protect and support this part during the assembly process.',
#  'value': '100V 63A 78W 10.9mΩ@10V,46A N Channel DFN-8(5x6)  MOSFETs ROHS',
#  'type': 'mosfet',
#  'uuid': '42142935-f843-4140-b43d-3fef8f87cf78',
#  'Description': '100V 63A 78W 10.9mΩ@10V,46A N Channel DFN-8(5x6)  MOSFETs ROHS',
#  'Price': [{'quantity': '1+', 'price': 1.326},
#   {'quantity': '10+', 'price': 1.1325},
#   {'quantity': '30+', 'price': 1.026},
#   {'quantity': '100+', 'price': 0.906},
#   {'quantity': '500+', 'price': 0.726},
#   {'quantity': '1000+', 'price': 0.702}],
#  'Stock': 168,
#  'CAD Model': 'PCB Footprint or Symbol',
#  'Datasheet': 'Download',
#  'current_A': 63.0,
#  'on_resistance_ohms': 0.0109,
#  'Source': 'JLCPCB',
#  'Package': 'PDFN-8(5.2x6.2)',
#  'drain_source_voltage_V': 100,
#  'MFR.Part #': 'BSC109N10NS3G',
#  'footprint': {'kicad': 'PDFN-8(5.2x6.2)-42142935-f843-4140-b43d-3fef8f87cf78.kicad_mod'},
#  'Manufacturer': 'Infineon Technologies',
#  'power_dissipation_W': 78,
#  'LCSC Part #': 'C131006',
#  'polarity': 'N Channel',
#  'footprint_data': {'kicad': 'PDFN-8(5.2x6.2)-42142935-f843-4140-b43d-3fef8f87cf78.kicad_mod'}}

# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore
import uuid

# Reference to the 'mosfets' collection
mosfets_collection = db.collection('mosfets')

# Fetch all documents in the collection
docs = mosfets_collection.stream()

for doc in docs:
    doc_data = doc.to_dict()

    # Move the existing footprint data to 'footprint_data.kicad'
    current_footprint = doc_data.get('footprint').get('kicad')
    doc_data['footprint_data'] = {'kicad': current_footprint}

    # Update the document with new data
    mosfets_collection.document(doc.id).set(doc_data)

    print(f"Updated footprint for {doc_data.get('LCSC Part #', 'Unknown LCSC Part #')}")

print("Database update completed.")
# Out:
# Updated footprint for C105685
# Updated footprint for C10647
# Updated footprint for C10650
# Updated footprint for C10654
# Updated footprint for C10657
# Updated footprint for C10663
# Updated footprint for C10669
# Updated footprint for C106992
# Updated footprint for C107589
# Updated footprint for C108891
# Updated footprint for C109445
# Updated footprint for C110100
# Updated footprint for C110101
# Updated footprint for C110158
# Updated footprint for C110712
# Updated footprint for C110713
# Updated footprint for C110715
# Updated footprint for C110716
# Updated footprint for C110717
# Updated footprint for C110718
# Updated footprint for C110724
# Updated footprint for C110725
# Updated footprint for C111356
# Updated footprint for C111970
# Updated footprint for C111980
# Updated footprint for C112722
# Updated footprint for C113315
# Updated footprint for C115168
# Updated footprint for C115827
# Updated footprint for C115828
# Updated footprint for C115829
# Updated footprint for C115833
# Updated footprint for C115835
# Updated footprint for C115840
# Updated footprint for C115841
# Updated footprint for C115843
# Updated footprint for C115845
# Updated footprint for C127272
# Updated footprint for C127857
# Updated footprint for C127863
# Updated footprint for C127907
# Updated footprint for C129135
# Updated footprint for C129166
# Updated footprint for C130365
# Updated footprint for C130424
# Updated footprint for C130980
# Updated footprint for C130986
# Updated footprint for C131006
# Updated footprint for C131012
# Updated footprint for C131033
# Updated footprint for C131676
# Updated footprint for C133596
# Updated footprint for C133597
# Updated footprint for C133598
# Updated footprint for C133599
# Updated footprint for C133603
# Updated footprint for C133604
# Updated footprint for C134143
# Updated footprint for C134160
# Updated footprint for C136034
# Updated footprint for C13898
# Updated footprint for C13899
# Updated footprint for C13914
# Updated footprint for C141748
# Updated footprint for C141823
# Updated footprint for C141847
# Updated footprint for C142374
# Updated footprint for C143031
# Updated footprint for C143032
# Updated footprint for C143070
# Updated footprint for C143650
# Updated footprint for C143655
# Updated footprint for C143656
# Updated footprint for C143657
# Updated footprint for C143659
# Updated footprint for C143661
# Updated footprint for C169761
# Updated footprint for C169762
# Updated footprint for C169763
# Updated footprint for C169768
# Updated footprint for C169769
# Updated footprint for C17098
# Updated footprint for C171509
# Updated footprint for C171511
# Updated footprint for C171512
# Updated footprint for C171513
# Updated footprint for C171514
# Updated footprint for C171515
# Updated footprint for C171516
# Updated footprint for C171525
# Updated footprint for C171526
# Updated footprint for C171527
# Updated footprint for C171528
# Updated footprint for C171529
# Updated footprint for C171530
# Updated footprint for C171532
# Updated footprint for C171533
# Updated footprint for C171534
# Updated footprint for C171535
# Updated footprint for C171536
# Updated footprint for C171537
# Updated footprint for C171538
# Updated footprint for C171539
# Updated footprint for C171540
# Updated footprint for C171541
# Updated footprint for C171553
# Updated footprint for C171554
# Updated footprint for C171555
# Updated footprint for C171556
# Updated footprint for C171558
# Updated footprint for C171559
# Updated footprint for C171561
# Updated footprint for C171562
# Updated footprint for C171563
# Updated footprint for C171564
# Updated footprint for C171565
# Updated footprint for C174045
# Updated footprint for C174046
# Updated footprint for C179750
# Updated footprint for C179753
# Updated footprint for C180375
# Updated footprint for C180376
# Updated footprint for C180399
# Updated footprint for C181036
# Updated footprint for C181082
# Updated footprint for C181083
# Updated footprint for C181084
# Updated footprint for C181086
# Updated footprint for C181087
# Updated footprint for C181088
# Updated footprint for C181089
# Updated footprint for C181090
# Updated footprint for C181091
# Updated footprint for C181092
# Updated footprint for C181093
# Updated footprint for C181094
# Updated footprint for C181095
# Updated footprint for C182999
# Updated footprint for C184182
# Updated footprint for C184252
# Updated footprint for C184823
# Updated footprint for C184834
# Updated footprint for C184884
# Updated footprint for C190607
# Updated footprint for C194346
# Updated footprint for C194959
# Updated footprint for C22162
# Updated footprint for C23982
# Updated footprint for C2557
# Updated footprint for C2559
# Updated footprint for C2560
# Updated footprint for C2561
# Updated footprint for C2562
# Updated footprint for C2563
# Updated footprint for C2564
# Updated footprint for C2565
# Updated footprint for C2566
# Updated footprint for C2567
# Updated footprint for C2568
# Updated footprint for C2570
# Updated footprint for C2571
# Updated footprint for C2572
# Updated footprint for C2573
# Updated footprint for C2574
# Updated footprint for C2575
# Updated footprint for C2576
# Updated footprint for C2577
# Updated footprint for C2578
# Updated footprint for C2580
# Updated footprint for C2582
# Updated footprint for C2583
# Updated footprint for C2584
# Updated footprint for C2585
# Updated footprint for C2586
# Updated footprint for C2587
# Updated footprint for C2588
# Updated footprint for C2589
# Updated footprint for C2590
# Updated footprint for C2591
# Updated footprint for C2592
# Updated footprint for C2593
# Updated footprint for C2594
# Updated footprint for C2595
# Updated footprint for C2596
# Updated footprint for C2597
# Updated footprint for C2598
# Updated footprint for C2599
# Updated footprint for C2600
# Updated footprint for C2601
# Updated footprint for C2602
# Updated footprint for C2603
# Updated footprint for C2605
# Updated footprint for C2607
# Updated footprint for C2608
# Updated footprint for C2609
# Updated footprint for C2610
# Updated footprint for C2611
# Updated footprint for C2612
# Updated footprint for C2613
# Updated footprint for C2614
# Updated footprint for C2615
# Updated footprint for C2616
# Updated footprint for C2617
# Updated footprint for C2618
# Updated footprint for C2619
# Updated footprint for C2620
# Updated footprint for C2621
# Updated footprint for C2623
# Updated footprint for C2624
# Updated footprint for C2625
# Updated footprint for C2626
# Updated footprint for C2627
# Updated footprint for C2628
# Updated footprint for C2630
# Updated footprint for C2631
# Updated footprint for C2632
# Updated footprint for C2633
# Updated footprint for C2634
# Updated footprint for C2635
# Updated footprint for C2636
# Updated footprint for C2637
# Updated footprint for C2641
# Updated footprint for C2642
# Updated footprint for C2643
# Updated footprint for C2644
# Updated footprint for C2645
# Updated footprint for C2647
# Updated footprint for C2648
# Updated footprint for C2649
# Updated footprint for C2650
# Updated footprint for C2651
# Updated footprint for C2652
# Updated footprint for C2653
# Updated footprint for C2655
# Updated footprint for C2656
# Updated footprint for C2657
# Updated footprint for C2658
# Updated footprint for C2659
# Updated footprint for C2662
# Updated footprint for C2663
# Updated footprint for C2664
# Updated footprint for C2665
# Updated footprint for C2666
# Updated footprint for C2667
# Updated footprint for C2668
# Updated footprint for C2669
# Updated footprint for C2670
# Updated footprint for C2671
# Updated footprint for C2672
# Updated footprint for C2673
# Updated footprint for C2674
# Updated footprint for C2675
# Updated footprint for C2676
# Updated footprint for C2678
# Updated footprint for C2679
# Updated footprint for C2680
# Updated footprint for C2681
# Updated footprint for C2682
# Updated footprint for C2683
# Updated footprint for C2684
# Updated footprint for C2685
# Updated footprint for C2686
# Updated footprint for C2687
# Updated footprint for C2688
# Updated footprint for C2689
# Updated footprint for C2690
# Updated footprint for C2694
# Updated footprint for C2695
# Updated footprint for C2696
# Updated footprint for C2697
# Updated footprint for C2698
# Updated footprint for C2701
# Updated footprint for C2702
# Updated footprint for C2703
# Updated footprint for C2704
# Updated footprint for C2705
# Updated footprint for C2706
# Updated footprint for C2710
# Updated footprint for C2711
# Updated footprint for C2712
# Updated footprint for C27159
# Updated footprint for C2718
# Updated footprint for C2719
# Updated footprint for C2720
# Updated footprint for C28369
# Updated footprint for C28532
# Updated footprint for C2916
# Updated footprint for C2917
# Updated footprint for C2918
# Updated footprint for C2919
# Updated footprint for C2920
# Updated footprint for C2921
# Updated footprint for C2922
# Updated footprint for C2923
# Updated footprint for C2924
# Updated footprint for C2925
# Updated footprint for C2926
# Updated footprint for C2927
# Updated footprint for C2928
# Updated footprint for C2929
# Updated footprint for C2930
# Updated footprint for C2931
# Updated footprint for C2932
# Updated footprint for C2933
# Updated footprint for C2934
# Updated footprint for C2935
# Updated footprint for C2936
# Updated footprint for C2997
# Updated footprint for C2998
# Updated footprint for C3000
# Updated footprint for C3001
# Updated footprint for C3002
# Updated footprint for C3003
# Updated footprint for C3005
# Updated footprint for C3007
# Updated footprint for C3008
# Updated footprint for C3010
# Updated footprint for C3012
# Updated footprint for C3014
# Updated footprint for C3015
# Updated footprint for C3017
# Updated footprint for C3018
# Updated footprint for C3019
# Updated footprint for C3021
# Updated footprint for C3022
